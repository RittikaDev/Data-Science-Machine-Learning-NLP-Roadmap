# %% [markdown]
# ##### Standard Library Overview
# Python's Standard Library is a vast collection of modules and packages that come bundled with Python, providing a wide range of functionalities out of the box. Here's an overview of some of the most commonly used modules and packages in the Python Standard Library.

# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## RANDOM 

import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 2
# cherry

# %%
### FILE AND DIRECTORY ACCESS

import os
print(os.getcwd()) ## CURRENT WORKING DIRECTORY
# Out:
# e:\R&D\Python\Udemy\Complete Data Science, Machine Learning ,DL, NLP Bootcamp === Krish Naik KRISHAI Technologies Private Limited\code\Practice\5-Modules

# %%
os.mkdir('test_dir')

# %%
## HIGH LEVEL OPERATIONS ON FILES AND COLLECTION OF FILES
import shutil
shutil.copyfile('source.txt','destination.txt') ## COPY FROM source.txt, PASTE TO destination.txt
# Out:
# 'destination.txt'

# %%
## DATA SERIALIZATION
import json
data={'name':'Krish','age':25}

json_str=json.dumps(data) # CONVERT PYTHON OBJECT TO JSON STRING
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str) # CONVERT JSON STRING BACK TO PYTHON OBJECT
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Krish", "age": 25}
# <class 'str'>
# {'name': 'Krish', 'age': 25}
# <class 'dict'>

# %%
## CSV

import csv

with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Krish',32])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Krish', '32']

# %%
## DATETIME
from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)

print(yesterday)
# Out:
# 2024-06-11 11:37:28.084474
# 2024-06-10 11:37:28.084474

# %%
## TIME
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1718086104.8242216
# 1718086106.82563

# %%
## REGULAR EXPRESIION
import re

pattern=r'\d+'
text='There are 123 apples 456'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123

# %% [markdown]
# #### Conclusion
# Python's Standard Library is extensive and provides tools for almost any task you can think of, from file handling to web services, from data serialization to concurrent execution. Familiarizing yourself with the modules and packages available in the Standard Library can significantly enhance your ability to write efficient and effective Python programs.
